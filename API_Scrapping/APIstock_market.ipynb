# %%
# %pip install python-dotenv
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install plotly
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
import os
api_key = os.getenv("API_KEY")

# %%
import requests

url = "https://alpha-vantage.p.rapidapi.com/query"

querystring = {"function":"TIME_SERIES_DAILY","symbol":"MSFT","outputsize":"compact","datatype":"json"}

headers = {
	"x-rapidapi-key": "70d677d789mshd725219844bf02bp14d743jsn53ae24694044",
	"x-rapidapi-host": "alpha-vantage.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

data = (response.json())
data
# Out:
# {'Meta Data': {'1. Information': 'Daily Prices (open, high, low, close) and Volumes',
#   '2. Symbol': 'MSFT',
#   '3. Last Refreshed': '2025-07-18',
#   '4. Output Size': 'Compact',
#   '5. Time Zone': 'US/Eastern'},
#  'Time Series (Daily)': {'2025-07-18': {'1. open': '514.4800',
#    '2. high': '514.6400',
#    '3. low': '507.4300',
#    '4. close': '510.0500',
#    '5. volume': '21209666'},
#   '2025-07-17': {'1. open': '505.6800',
#    '2. high': '513.3700',
#    '3. low': '505.6200',
#    '4. close': '511.7000',
#    '5. volume': '17503129'},
#   '2025-07-16': {'1. open': '505.1800',
#    '2. high': '506.7200',
#    '3. low': '501.8900',
#    '4. close': '505.6200',
#    '5. volume': '15154374'},
#   '2025-07-15': {'1. open': '503.0200',
#    '2. high': '508.3000',
#    '3. low': '502.7900',
#    '4. close': '505.8200',
#    '5. volume': '14927202'},
#   '2025-07-14': {'1. open': '501.5150',
#    '2. high': '503.9700',
#    '3. low': '501.0300',
#    '4. close': '503.0200',
# ...

# %%
#Fetch Data
import requests

url = "https://alpha-vantage.p.rapidapi.com/query"

querystring = {"function":"TIME_SERIES_DAILY","symbol":"GODREJCP.BSE","outputsize":"compact","datatype":"json"}

headers = {
	"x-rapidapi-key": api_key,
	"x-rapidapi-host": "alpha-vantage.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

data1 = (response.json())
data1
# Out:
# {'Meta Data': {'1. Information': 'Daily Prices (open, high, low, close) and Volumes',
#   '2. Symbol': 'GODREJCP.BSE',
#   '3. Last Refreshed': '2025-07-18',
#   '4. Output Size': 'Compact',
#   '5. Time Zone': 'US/Eastern'},
#  'Time Series (Daily)': {'2025-07-18': {'1. open': '1282.0000',
#    '2. high': '1283.0000',
#    '3. low': '1246.1000',
#    '4. close': '1252.1500',
#    '5. volume': '3918'},
#   '2025-07-17': {'1. open': '1264.5500',
#    '2. high': '1283.2000',
#    '3. low': '1262.8000',
#    '4. close': '1275.1500',
#    '5. volume': '7233'},
#   '2025-07-16': {'1. open': '1266.2000',
#    '2. high': '1269.6500',
#    '3. low': '1254.7000',
#    '4. close': '1264.2000',
#    '5. volume': '2983'},
#   '2025-07-15': {'1. open': '1268.0000',
#    '2. high': '1276.2000',
#    '3. low': '1261.4000',
#    '4. close': '1269.7000',
#    '5. volume': '4435'},
#   '2025-07-14': {'1. open': '1285.0000',
#    '2. high': '1288.5000',
#    '3. low': '1264.1500',
# ...

# %%
# %pip install lxml
# Out:
# ...
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ------- -------------------------------- 0.8/4.0 MB 4.3 MB/s eta 0:00:01
#    -------------------- ------------------- 2.1/4.0 MB 5.5 MB/s eta 0:00:01
#    ------------------------------------ --- 3.7/4.0 MB 6.1 MB/s eta 0:00:01
#    ---------------------------------------- 4.0/4.0 MB 5.5 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
